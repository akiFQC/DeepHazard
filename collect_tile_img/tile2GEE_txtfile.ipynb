# %%
import glob 
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torchvision.transforms.functional as TF
from functools import lru_cache
    
import torch
import torchvision


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torch import optim 

from tqdm.notebook import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls '/content/drive/My Drive'

path = "/content/drive/My Drive/SpaceAppsChallenge2020/data/hazard_img/標高/関東平野/z14/"
path_dir_target = "/content/drive/My Drive/SpaceAppsChallenge2020/data/hazard_img/洪水/関東平野/z14"

# !ls
# !cd "/content/drive/My Drive/SpaceAppsChallenge2020/data/hazard_img/標高/関東平野/z14"
# !ls

files = os.listdir(path)
files_file = [f for f in files if os.path.isfile(os.path.join(path, f))]
print(files_file)   # ['file1', 'file2.txt', 'file3.jpg']



path_w = '/content/drive/My Drive/SpaceAppsChallenge2020/data/hazard_img/標高/関東平野/position.txt'

from math import pi
from math import e, log
from math import atan, tan

def tile2longlati(x, y, z):
	long_west = (x / 2.0**z) * 360 - 180 # 西端経度
	long_east = ((x+1) / 2.0**z) * 360 - 180 # 東端経度
	map_y1 = (y / 2.0**z) * 2 * pi - pi
	map_y2 = ((y+1) / 2.0**z) * 2 * pi - pi
	lati_north = 2 * atan(e ** (- map_y1)) * 180 / pi - 90 # 北端緯度
	lati_south = 2 * atan(e ** (- map_y2)) * 180 / pi - 90 # 南端緯度
	return lati_south, long_west, lati_north, long_east #南端、西端、北端、東端

for file_name in files_file:
  a=file_name.split('_')
  print(a)
  z=int(a[0])
  x=int(a[1])
  y_str=a[2]
  y=int(y_str[:-4])
  lati_south, long_west, lati_north, long_east=tile2longlati(x,y,z)
  print(lati_south, long_west, lati_north, long_east)
  s=str(lati_south)+","+str(long_west)+","+str(lati_north)+","+str(long_east)+"\n"
  with open(path_w, mode='a') as f:
    f.write(s)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# 36.4566360115962 139.2626953125 36.47430675509521 139.28466796875
# ['14', '14530', '6409.png']
# 36.42128244364946 139.2626953125 36.43896124085947 139.28466796875
# ['14', '14530', '6411.png']
# 36.38591277287651 139.2626953125 36.403599620732535 139.28466796875
# ['14', '14530', '6416.png']
# 36.29741818650811 139.2626953125 36.3151251474805 139.28466796875
# ['14', '14530', '6422.png']
# 36.19109202182453 139.2626953125 36.20882309283712 139.28466796875
# ['14', '14530', '6421.png']
# 36.20882309283712 139.2626953125 36.2265501474709 139.28466796875
# ['14', '14530', '6419.png']
# 36.24427318493909 139.2626953125 36.26199220445662 139.28466796875
# ['14', '14530', '6415.png']
# 36.3151251474805 139.2626953125 36.332828087379156 139.28466796875
# ['14', '14530', '6418.png']
# 36.26199220445662 139.2626953125 36.27970720524017 139.28466796875
# ['14', '14530', '6423.png']
# 36.17335693522156 139.2626953125 36.19109202182453 139.28466796875
# ...
